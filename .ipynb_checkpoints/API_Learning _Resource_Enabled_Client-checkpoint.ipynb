# %%
import requests
import base64
import datetime
from urllib.parse import urlencode

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import time
import re
import json
from datetime import datetime, time, date

import datetime
import time

from requests.exceptions import SSLError

from sklearn.preprocessing import OneHotEncoder

# %%
client_id = 'f78a4f4cfe9c40ea8fe346b0576e98ea'
client_secret = 'c26db2d4c1fb42d79dc99945b2360ab4'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        '''
        returns a base 64 encoded string
        '''
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("Must set client_id and client_secret")
        client_creds = f'{client_id}:{client_secret}'
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_header(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            'Authorization' : f'Basic {client_creds_b64}' # Basic <base64 encoded client_id:client_secret>
        }
    
    def get_token_data(self):
        return {
            'grant_type': 'client_credentials'
        }
    
    def auth(self):
        token_data = self.get_token_data()
        token_headers = self.get_token_header()
        token_url = self.token_url

        
        r = requests.post(token_url, data = token_data, headers = token_headers)
        
        
        if r.status_code not in range (200, 299):
            return False
        token_response_data = r.json()
        now = datetime.datetime.now()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        self.access_token = access_token
        return True
        
    def searchTrack(self, item):
        access_token = self.access_token
        
        headers = {
            'Authorization': f'Bearer {access_token}'
        }

        endpoint = 'https://api.spotify.com/v1/search'
        data = urlencode({'q': item, 'type':'track'})

        lookup_url = f'{endpoint}?{data}'
        print(lookup_url)

        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        return r.json()
    
    def searchAlbum(self, item):
        access_token = self.access_token
        
        headers = {
            'Authorization': f'Bearer {access_token}'
        }

        endpoint = 'https://api.spotify.com/v1/search'
        data = urlencode({'q': item, 'type':'album'})

        lookup_url = f'{endpoint}?{data}'
        print(lookup_url)

        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        return r.json()
    
    def searchArtist(self, item):
        access_token = self.access_token
        
        headers = {
            'Authorization': f'Bearer {access_token}'
        }

        endpoint = 'https://api.spotify.com/v1/search'
        data = urlencode({'q': item, 'type':'artist'})

        lookup_url = f'{endpoint}?{data}'
        print(lookup_url)

        r = requests.get(lookup_url, headers=headers)
        print(r.status_code)
        return r.json()

# %%
client = SpotifyAPI(client_id, client_secret)
client.auth()
# Out:
# True

# %%
r = client.searchArtist('the eden project')
r['artists']['items'][0]['genres']
# Out:
# https://api.spotify.com/v1/search?q=the+eden+project&type=artist
# 200
# ['indie poptimism', 'modern rock', 'pop', 'pop rap']

# %%
# Set Up Streaming History
streamingHistory = []

for f in os.listdir('data/data_2019'):
    if f.startswith('StreamingHistory'):
        streamingHistory.append(pd.read_json(os.path.join('data/data_2019', f)))
    
        
rawHist = pd.concat(streamingHistory).reset_index(drop=True)

# %%
rawHist
# Out:
#                 endTime           artistName                    trackName  \
# 0      2018-11-14 00:01      Imagine Dragons                        Stuck
# 1      2018-11-14 00:04      Imagine Dragons                         Love
# 2      2018-11-14 00:08      Imagine Dragons                        Birds
# 3      2018-11-14 00:12      Imagine Dragons                     Burn Out
# 4      2018-11-14 00:16      Imagine Dragons                    Real Life
# ...                 ...                  ...                          ...
# 30822  2019-11-14 23:32  My Chemical Romance  Welcome to the Black Parade
# 30823  2019-11-14 23:34          Tony Molina               Jasper's Theme
# 30824  2019-11-14 23:38      Imagine Dragons                     Cool Out
# 30825  2019-11-14 23:41  5 Seconds of Summer          If Walls Could Talk
# 30826  2019-11-14 23:44      Imagine Dragons                    Boomerang
#
#        msPlayed
# 0        190853
# 1        166360
# 2        219440
# 3        273880
# 4        247546
# ...         ...
# 30822    311106
# 30823    121509
# 30824    217866
# 30825    182292
# 30826    187800
#
# [30827 rows x 4 columns]

# %%
artists = rawHist['artistName'].unique()
genreList = []
skippedList = []
painCount = 0
painOffset = 0
i = 0
while i < len(artists):
    try:
        print(i - painOffset)
        r = client.searchArtist(artists[i - painOffset])

        # Make sure the query returns something
        if len(r['artists']['items']) != 0:
            print('APPENDED GENRE')
            genreList.append(r['artists']['items'][0]['genres'])
        else:
            print('APPENDED NAN')
            genreList.append(np.nan)
            
        i += 1

        
    except SSLError:
        painCount += 1
        print("HELP HELP HELP HELP")
        
            
print(painCount)
# Out:
# 0
# https://api.spotify.com/v1/search?q=Imagine+Dragons&type=artist
# 200
# APPENDED GENRE
# 1
# https://api.spotify.com/v1/search?q=iLOVEFRiDAY&type=artist
# 200
# APPENDED GENRE
# 2
# https://api.spotify.com/v1/search?q=Panic%21+At+The+Disco&type=artist
# 200
# APPENDED GENRE
# 3
# https://api.spotify.com/v1/search?q=Oliver+Tree&type=artist
# 200
# APPENDED GENRE
# 4
# https://api.spotify.com/v1/search?q=88rising&type=artist
# 200
# APPENDED GENRE
# 5
# https://api.spotify.com/v1/search?q=bbno%24&type=artist
# 200
# APPENDED GENRE
# 6
# https://api.spotify.com/v1/search?q=atlas&type=artist
# 200
# APPENDED GENRE
# 7
# https://api.spotify.com/v1/search?q=Yung+Gravy&type=artist
# 200
# APPENDED GENRE
# 8
# https://api.spotify.com/v1/search?q=Joji&type=artist
# 200
# APPENDED GENRE
# 9
# https://api.spotify.com/v1/search?q=BROCKHAMPTON&type=artist
# 200
# APPENDED GENRE
# 10
# https://api.spotify.com/v1/search?q=Iamjakehill&type=artist
# 200
# APPENDED GENRE
# 11
# https://api.spotify.com/v1/search?q=Rich+Brian&type=artist
# 200
# APPENDED GENRE
# 12
# https://api.spotify.com/v1/search?q=Getter&type=artist
# 200
# APPENDED GENRE
# 13
# https://api.spotify.com/v1/search?q=Gus+Dapperton&type=artist
# 200
# APPENDED GENRE
# 14
# https://api.spotify.com/v1/search?q=Kevin+Abstract&type=artist
# 200
# APPENDED GENRE
# 15
# https://api.spotify.com/v1/search?q=Jaden&type=artist
# 200
# APPENDED GENRE
# 16
# https://api.spotify.com/v1/search?q=rei+brown&type=artist
# 200
# APPENDED GENRE
# 17
# https://api.spotify.com/v1/search?q=Hobo+Johnson&type=artist
# 200
# APPENDED GENRE
# 18
# https://api.spotify.com/v1/search?q=Samsa&type=artist
# 200
# APPENDED GENRE
# 19
# https://api.spotify.com/v1/search?q=Josh+A&type=artist
# 200
# APPENDED GENRE
# 20
# https://api.spotify.com/v1/search?q=Verzache&type=artist
# 200
# APPENDED GENRE
# 21
# https://api.spotify.com/v1/search?q=zack+villere&type=artist
# 200
# APPENDED GENRE
# 22
# https://api.spotify.com/v1/search?q=Yeek&type=artist
# 200
# APPENDED GENRE
# 23
# https://api.spotify.com/v1/search?q=Meltycanon&type=artist
# 200
# APPENDED GENRE
# 24
# https://api.spotify.com/v1/search?q=Twenty+One+Pilots&type=artist
# 200
# APPENDED GENRE
# 25
# https://api.spotify.com/v1/search?q=Martin+Garrix&type=artist
# 200
# APPENDED GENRE
# 26
# https://api.spotify.com/v1/search?q=Alan+Walker&type=artist
# 200
# APPENDED GENRE
# 27
# https://api.spotify.com/v1/search?q=AJR&type=artist
# 200
# APPENDED GENRE
# 28
# https://api.spotify.com/v1/search?q=OneRepublic&type=artist
# 200
# APPENDED GENRE
# 29
# https://api.spotify.com/v1/search?q=Clean+Bandit&type=artist
# 200
# APPENDED GENRE
# 30
# https://api.spotify.com/v1/search?q=MKTO&type=artist
# 200
# APPENDED GENRE
# 31
# https://api.spotify.com/v1/search?q=Liam+Payne&type=artist
# 200
# APPENDED GENRE
# 32
# https://api.spotify.com/v1/search?q=Avicii&type=artist
# 200
# APPENDED GENRE
# 33
# https://api.spotify.com/v1/search?q=Owl+City&type=artist
# 200
# APPENDED GENRE
# 34
# https://api.spotify.com/v1/search?q=The+Chainsmokers&type=artist
# 200
# APPENDED GENRE
# 35
# https://api.spotify.com/v1/search?q=DNCE&type=artist
# 200
# APPENDED GENRE
# 36
# https://api.spotify.com/v1/search?q=EDEN&type=artist
# 200
# APPENDED GENRE
# 37
# https://api.spotify.com/v1/search?q=NateWantsToBattle&type=artist
# 200
# APPENDED GENRE
# 38
# https://api.spotify.com/v1/search?q=UVERworld&type=artist
# 200
# APPENDED GENRE
# 39
# https://api.spotify.com/v1/search?q=Anderson+.Paak&type=artist
# 200
# APPENDED GENRE
# 40
# https://api.spotify.com/v1/search?q=Odd+Future&type=artist
# 200
# APPENDED GENRE
# 41
# https://api.spotify.com/v1/search?q=Tay+Zonday&type=artist
# 200
# APPENDED GENRE
# 42
# https://api.spotify.com/v1/search?q=Polyphia&type=artist
# 200
# APPENDED GENRE
# 43
# https://api.spotify.com/v1/search?q=After+The+Burial&type=artist
# 200
# APPENDED GENRE
# 44
# https://api.spotify.com/v1/search?q=6ix9ine&type=artist
# 200
# APPENDED GENRE
# 45
# https://api.spotify.com/v1/search?q=Lil+Yachty&type=artist
# 200
# APPENDED GENRE
# 46
# https://api.spotify.com/v1/search?q=The+Contortionist&type=artist
# 200
# APPENDED GENRE
# 47
# https://api.spotify.com/v1/search?q=Vitalism&type=artist
# 200
# APPENDED GENRE
# 48
# https://api.spotify.com/v1/search?q=Between+The+Buried+And+Me&type=artist
# 200
# APPENDED GENRE
# 49
# https://api.spotify.com/v1/search?q=Monuments&type=artist
# 200
# APPENDED GENRE
# 50
# https://api.spotify.com/v1/search?q=Chon&type=artist
# 200
# APPENDED GENRE
# 51
# https://api.spotify.com/v1/search?q=Plini&type=artist
# 200
# APPENDED GENRE
# 52
# https://api.spotify.com/v1/search?q=Intervals&type=artist
# 200
# APPENDED GENRE
# 53
# https://api.spotify.com/v1/search?q=Eternity+Forever&type=artist
# 200
# APPENDED GENRE
# 54
# https://api.spotify.com/v1/search?q=TesseracT&type=artist
# 200
# APPENDED GENRE
# 55
# https://api.spotify.com/v1/search?q=Erra&type=artist
# 200
# APPENDED GENRE
# 56
# https://api.spotify.com/v1/search?q=Aries&type=artist
# 200
# APPENDED GENRE
# 57
# https://api.spotify.com/v1/search?q=Elohim&type=artist
# 200
# APPENDED GENRE
# 58
# https://api.spotify.com/v1/search?q=Still+Woozy&type=artist
# 200
# APPENDED GENRE
# 59
# https://api.spotify.com/v1/search?q=The+War+On+Drugs&type=artist
# 200
# APPENDED GENRE
# 60
# https://api.spotify.com/v1/search?q=Frank+Ocean&type=artist
# 200
# APPENDED GENRE
# 61
# https://api.spotify.com/v1/search?q=JID&type=artist
# 200
# APPENDED GENRE
# 62
# https://api.spotify.com/v1/search?q=MF+DOOM&type=artist
# 200
# APPENDED GENRE
# 63
# https://api.spotify.com/v1/search?q=Aesop+Rock&type=artist
# 200
# APPENDED GENRE
# 64
# https://api.spotify.com/v1/search?q=Dbangz&type=artist
# 200
# APPENDED GENRE
# 65
# https://api.spotify.com/v1/search?q=Terror+Reid&type=artist
# 200
# APPENDED GENRE
# 66
# https://api.spotify.com/v1/search?q=Tyler%2C+The+Creator&type=artist
# 200
# APPENDED GENRE
# 67
# https://api.spotify.com/v1/search?q=Travis+Scott&type=artist
# 200
# APPENDED GENRE
# 68
# https://api.spotify.com/v1/search?q=ScHoolboy+Q&type=artist
# 200
# APPENDED GENRE
# 69
# https://api.spotify.com/v1/search?q=KIDS+SEE+GHOSTS&type=artist
# 200
# APPENDED GENRE
# 70
# https://api.spotify.com/v1/search?q=Vince+Staples&type=artist
# 200
# APPENDED GENRE
# 71
# https://api.spotify.com/v1/search?q=Knowmadic&type=artist
# 200
# APPENDED GENRE
# 72
# https://api.spotify.com/v1/search?q=Tragic+Young+Existence&type=artist
# 200
# APPENDED GENRE
# 73
# https://api.spotify.com/v1/search?q=Atwood&type=artist
# 200
# APPENDED GENRE
# 74
# https://api.spotify.com/v1/search?q=A-Kil&type=artist
# 200
# APPENDED GENRE
# 75
# https://api.spotify.com/v1/search?q=Lil+Xan&type=artist
# 200
# APPENDED GENRE
# 76
# https://api.spotify.com/v1/search?q=Noah+Cyrus&type=artist
# 200
# APPENDED GENRE
# 77
# https://api.spotify.com/v1/search?q=Diplo&type=artist
# 200
# APPENDED GENRE
# 78
# https://api.spotify.com/v1/search?q=5+Seconds+of+Summer&type=artist
# 200
# APPENDED GENRE
# 79
# https://api.spotify.com/v1/search?q=Pink+Guy&type=artist
# 200
# APPENDED GENRE
# 80
# https://api.spotify.com/v1/search?q=ROSAL%C3%83%EF%BF%BDA&type=artist
# 200
# APPENDED GENRE
# 81
# https://api.spotify.com/v1/search?q=Run%C3%A2%E2%82%AC%E2%80%9CD.M.C.&type=artist
# 200
# APPENDED GENRE
# 82
# https://api.spotify.com/v1/search?q=Gucci+Mane&type=artist
# 200
# APPENDED GENRE
# 83
# https://api.spotify.com/v1/search?q=Eazy-E&type=artist
# 200
# APPENDED GENRE
# 84
# https://api.spotify.com/v1/search?q=Mariah+Carey&type=artist
# 200
# APPENDED GENRE
# 85
# https://api.spotify.com/v1/search?q=DRAM&type=artist
# 200
# APPENDED GENRE
# 86
# https://api.spotify.com/v1/search?q=Idealism&type=artist
# 200
# APPENDED GENRE
# 87
# https://api.spotify.com/v1/search?q=Tomppabeats&type=artist
# 200
# APPENDED GENRE
# 88
# https://api.spotify.com/v1/search?q=Oatmello&type=artist
# 200
# APPENDED GENRE
# 89
# https://api.spotify.com/v1/search?q=Cookin+Soul&type=artist
# 200
# APPENDED GENRE
# 90
# https://api.spotify.com/v1/search?q=The+Deli&type=artist
# 200
# APPENDED GENRE
# 91
# https://api.spotify.com/v1/search?q=Baraka&type=artist
# 200
# APPENDED GENRE
# 92
# https://api.spotify.com/v1/search?q=emune&type=artist
# 200
# APPENDED GENRE
# 93
# https://api.spotify.com/v1/search?q=McClenney&type=artist
# 200
# APPENDED GENRE
# 94
# https://api.spotify.com/v1/search?q=Nohidea&type=artist
# 200
# APPENDED GENRE
# 95
# https://api.spotify.com/v1/search?q=Otesla&type=artist
# 200
# APPENDED GENRE
# 96
# https://api.spotify.com/v1/search?q=Aso&type=artist
# 200
# APPENDED GENRE
# 97
# https://api.spotify.com/v1/search?q=Joey+Pecoraro&type=artist
# 200
# APPENDED GENRE
# 98
# https://api.spotify.com/v1/search?q=eevee&type=artist
# 200
# APPENDED GENRE
# 99
# https://api.spotify.com/v1/search?q=Waahiid&type=artist
# 200
# APPENDED GENRE
# 100
# https://api.spotify.com/v1/search?q=TOSHIKI+HAYASHI%28%25C%29&type=artist
# 200
# APPENDED GENRE
# 101
# https://api.spotify.com/v1/search?q=Limes&type=artist
# 200
# APPENDED GENRE
# 102
# https://api.spotify.com/v1/search?q=baaskaT&type=artist
# 200
# APPENDED GENRE
# 103
# https://api.spotify.com/v1/search?q=Mura+Kami&type=artist
# 200
# APPENDED GENRE
# 104
# https://api.spotify.com/v1/search?q=Hue+Honey&type=artist
# 200
# APPENDED GENRE
# 105
# https://api.spotify.com/v1/search?q=%5Bbsd.u%5D&type=artist
# 200
# APPENDED GENRE
# 106
# https://api.spotify.com/v1/search?q=Chance+Thrash&type=artist
# 200
# APPENDED GENRE
# 107
# https://api.spotify.com/v1/search?q=Valntn&type=artist
# 200
# APPENDED GENRE
# 108
# https://api.spotify.com/v1/search?q=Squid+Ethics&type=artist
# 200
# APPENDED GENRE
# 109
# https://api.spotify.com/v1/search?q=The+1975&type=artist
# 200
# APPENDED GENRE
# 110
# https://api.spotify.com/v1/search?q=Fall+Out+Boy&type=artist
# 200
# APPENDED GENRE
# 111
# https://api.spotify.com/v1/search?q=Drake&type=artist
# 200
# APPENDED GENRE
# 112
# https://api.spotify.com/v1/search?q=Kesha&type=artist
# 200
# APPENDED GENRE
# 113
# https://api.spotify.com/v1/search?q=Viktor+Vaughn&type=artist
# 200
# APPENDED GENRE
# 114
# https://api.spotify.com/v1/search?q=Keala+Settle&type=artist
# 200
# APPENDED GENRE
# 115
# https://api.spotify.com/v1/search?q=Pitbull&type=artist
# 200
# APPENDED GENRE
# 116
# https://api.spotify.com/v1/search?q=Iggy+Azalea&type=artist
# 200
# APPENDED GENRE
# 117
# https://api.spotify.com/v1/search?q=Iggy+Pop&type=artist
# 200
# APPENDED GENRE
# 118
# https://api.spotify.com/v1/search?q=Daniel+Caesar&type=artist
# 200
# APPENDED GENRE
# 119
# https://api.spotify.com/v1/search?q=Kali+Uchis&type=artist
# 200
# APPENDED GENRE
# 120
# https://api.spotify.com/v1/search?q=Substantial&type=artist
# 200
# APPENDED GENRE
# 121
# https://api.spotify.com/v1/search?q=Chance+the+Rapper&type=artist
# 200
# APPENDED GENRE
# 122
# https://api.spotify.com/v1/search?q=Amin%C3%83%C2%A9&type=artist
# 200
# APPENDED GENRE
# 123
# https://api.spotify.com/v1/search?q=H.E.R.&type=artist
# 200
# APPENDED GENRE
# 124
# https://api.spotify.com/v1/search?q=ItaloBrothers&type=artist
# 200
# APPENDED GENRE
# 125
# https://api.spotify.com/v1/search?q=Omar+Apollo&type=artist
# 200
# APPENDED GENRE
# 126
# https://api.spotify.com/v1/search?q=Rex+Orange+County&type=artist
# 200
# APPENDED GENRE
# 127
# https://api.spotify.com/v1/search?q=Porter+Robinson&type=artist
# 200
# APPENDED GENRE
# 128
# https://api.spotify.com/v1/search?q=My+Chemical+Romance&type=artist
# 200
# APPENDED GENRE
# 129
# https://api.spotify.com/v1/search?q=potsu&type=artist
# 200
# APPENDED GENRE
# 130
# https://api.spotify.com/v1/search?q=Jukebox+The+Ghost&type=artist
# 200
# APPENDED GENRE
# 131
# https://api.spotify.com/v1/search?q=Future&type=artist
# 200
# APPENDED GENRE
# 132
# https://api.spotify.com/v1/search?q=Three+Days+Grace&type=artist
# 200
# APPENDED GENRE
# 133
# https://api.spotify.com/v1/search?q=XXXTENTACION&type=artist
# 200
# APPENDED GENRE
# 134
# https://api.spotify.com/v1/search?q=Shawn+Mendes&type=artist
# 200
# APPENDED GENRE
# 135
# https://api.spotify.com/v1/search?q=Gerard+Way&type=artist
# 200
# APPENDED GENRE
# 136
# https://api.spotify.com/v1/search?q=Lil+Peep&type=artist
# 200
# APPENDED GENRE
# 137
# https://api.spotify.com/v1/search?q=Pink+Floyd&type=artist
# 200
# APPENDED GENRE
# 138
# https://api.spotify.com/v1/search?q=Juice+WRLD&type=artist
# 200
# APPENDED GENRE
# 139
# https://api.spotify.com/v1/search?q=6LACK&type=artist
# 200
# APPENDED GENRE
# 140
# https://api.spotify.com/v1/search?q=Ski+Mask+The+Slump+God&type=artist
# 200
# APPENDED GENRE
# 141
# https://api.spotify.com/v1/search?q=Flipp+Dinero&type=artist
# 200
# APPENDED GENRE
# 142
# https://api.spotify.com/v1/search?q=Comethazine&type=artist
# 200
# APPENDED GENRE
# 143
# https://api.spotify.com/v1/search?q=6+Dogs&type=artist
# 200
# APPENDED GENRE
# 144
# https://api.spotify.com/v1/search?q=Paris+Shadows&type=artist
# 200
# APPENDED GENRE
# 145
# https://api.spotify.com/v1/search?q=Lil+Skies&type=artist
# 200
# APPENDED GENRE
# 146
# https://api.spotify.com/v1/search?q=Trippie+Redd&type=artist
# 200
# APPENDED GENRE
# 147
# https://api.spotify.com/v1/search?q=NAV&type=artist
# 200
# APPENDED GENRE
# 148
# https://api.spotify.com/v1/search?q=Denzel+Curry&type=artist
# 200
# APPENDED GENRE
# 149
# https://api.spotify.com/v1/search?q=Ronny+J&type=artist
# 200
# APPENDED GENRE
# 150
# https://api.spotify.com/v1/search?q=BlocBoy+JB&type=artist
# 200
# APPENDED GENRE
# 151
# https://api.spotify.com/v1/search?q=A+Boogie+Wit+da+Hoodie&type=artist
# 200
# APPENDED GENRE
# 152
# https://api.spotify.com/v1/search?q=Lil+Uzi+Vert&type=artist
# 200
# APPENDED GENRE
# 153
# https://api.spotify.com/v1/search?q=Famous+Dex&type=artist
# 200
# APPENDED GENRE
# 154
# https://api.spotify.com/v1/search?q=Bass+Santana&type=artist
# 200
# APPENDED GENRE
# 155
# https://api.spotify.com/v1/search?q=Bring+Me+The+Horizon&type=artist
# 200
# APPENDED GENRE
# 156
# https://api.spotify.com/v1/search?q=Unique+The+Artist&type=artist
# 200
# APPENDED GENRE
# 157
# https://api.spotify.com/v1/search?q=Julian+Casablancas&type=artist
# 200
# APPENDED GENRE
# 158
# https://api.spotify.com/v1/search?q=benny+blanco&type=artist
# 200
# APPENDED GENRE
# 159
# https://api.spotify.com/v1/search?q=Calvin+Harris&type=artist
# 200
# APPENDED GENRE
# 160
# https://api.spotify.com/v1/search?q=Raleigh+Ritchie&type=artist
# 200
# APPENDED GENRE
# 161
# https://api.spotify.com/v1/search?q=Manwolves&type=artist
# 200
# APPENDED GENRE
# 162
# https://api.spotify.com/v1/search?q=TiRon+%26+Ayomari&type=artist
# 200
# APPENDED GENRE
# 163
# https://api.spotify.com/v1/search?q=Remo+Drive&type=artist
# HELP HELP HELP HELP
# 163
# https://api.spotify.com/v1/search?q=Remo+Drive&type=artist
# 200
# APPENDED GENRE
# 164
# https://api.spotify.com/v1/search?q=Linkin+Park&type=artist
# 200
# APPENDED GENRE
# 165
# https://api.spotify.com/v1/search?q=Childish+Gambino&type=artist
# 200
# APPENDED GENRE
# 166
# https://api.spotify.com/v1/search?q=Lil+Baby&type=artist
# 200
# APPENDED GENRE
# 167
# https://api.spotify.com/v1/search?q=Cascada&type=artist
# 200
# APPENDED GENRE
# 168
# https://api.spotify.com/v1/search?q=Icona+Pop&type=artist
# 200
# APPENDED GENRE
# 169
# https://api.spotify.com/v1/search?q=LMFAO&type=artist
# 200
# APPENDED GENRE
# 170
# https://api.spotify.com/v1/search?q=Jason+Derulo&type=artist
# 200
# APPENDED GENRE
# 171
# https://api.spotify.com/v1/search?q=SOPHIE&type=artist
# 200
# APPENDED GENRE
# 172
# https://api.spotify.com/v1/search?q=Matinee&type=artist
# 200
# APPENDED GENRE
# 173
# https://api.spotify.com/v1/search?q=Iyaz&type=artist
# 200
# APPENDED GENRE
# 174
# https://api.spotify.com/v1/search?q=Lady+Gaga&type=artist
# 200
# APPENDED GENRE
# 175
# https://api.spotify.com/v1/search?q=Rihanna&type=artist
# 200
# APPENDED GENRE
# 176
# https://api.spotify.com/v1/search?q=The+Black+Keys&type=artist
# 200
# APPENDED GENRE
# 177
# https://api.spotify.com/v1/search?q=David+Guetta&type=artist
# 200
# APPENDED GENRE
# 178
# https://api.spotify.com/v1/search?q=Britney+Spears&type=artist
# 200
# APPENDED GENRE
# 179
# https://api.spotify.com/v1/search?q=The+Black+Eyed+Peas&type=artist
# 200
# APPENDED GENRE
# 180
# https://api.spotify.com/v1/search?q=OutKast&type=artist
# 200
# APPENDED GENRE
# 181
# https://api.spotify.com/v1/search?q=3OH%213&type=artist
# 200
# APPENDED GENRE
# 182
# https://api.spotify.com/v1/search?q=Carly+Rae+Jepsen&type=artist
# 200
# APPENDED GENRE
# 183
# https://api.spotify.com/v1/search?q=B.o.B&type=artist
# 200
# APPENDED GENRE
# 184
# https://api.spotify.com/v1/search?q=Travie+McCoy&type=artist
# 200
# APPENDED GENRE
# 185
# https://api.spotify.com/v1/search?q=Cobra+Starship&type=artist
# 200
# APPENDED GENRE
# 186
# https://api.spotify.com/v1/search?q=Kanye+West&type=artist
# 200
# APPENDED GENRE
# 187
# https://api.spotify.com/v1/search?q=Fergie&type=artist
# 200
# APPENDED GENRE
# 188
# https://api.spotify.com/v1/search?q=Maroon+5&type=artist
# 200
# APPENDED GENRE
# 189
# https://api.spotify.com/v1/search?q=Bruno+Mars&type=artist
# 200
# APPENDED GENRE
# 190
# https://api.spotify.com/v1/search?q=Post+Malone&type=artist
# 200
# APPENDED GENRE
# 191
# https://api.spotify.com/v1/search?q=Isaac+Lewis&type=artist
# 200
# APPENDED GENRE
# 192
# https://api.spotify.com/v1/search?q=Jon+Fratelli&type=artist
# 200
# APPENDED GENRE
# 193
# https://api.spotify.com/v1/search?q=Braxton+Cook&type=artist
# 200
# APPENDED GENRE
# 194
# https://api.spotify.com/v1/search?q=Flyleaf&type=artist
# 200
# APPENDED GENRE
# 195
# https://api.spotify.com/v1/search?q=khai+dreams&type=artist
# 200
# APPENDED GENRE
# 196
# https://api.spotify.com/v1/search?q=boy+pablo&type=artist
# 200
# APPENDED GENRE
# 197
# https://api.spotify.com/v1/search?q=Blai%24y&type=artist
# 200
# APPENDED GENRE
# 198
# https://api.spotify.com/v1/search?q=Roy+Blair&type=artist
# 200
# APPENDED GENRE
# 199
# https://api.spotify.com/v1/search?q=Dumbfoundead&type=artist
# 200
# APPENDED GENRE
# 200
# https://api.spotify.com/v1/search?q=Kodak+Black&type=artist
# 200
# APPENDED GENRE
# 201
# https://api.spotify.com/v1/search?q=Bing+Crosby&type=artist
# 200
# APPENDED GENRE
# 202
# https://api.spotify.com/v1/search?q=Kawfee&type=artist
# 200
# APPENDED GENRE
# 203
# https://api.spotify.com/v1/search?q=Kyo+Itachi&type=artist
# 200
# APPENDED GENRE
# 204
# https://api.spotify.com/v1/search?q=BluntOne&type=artist
# 200
# APPENDED GENRE
# 205
# https://api.spotify.com/v1/search?q=Gus+Glasser&type=artist
# 200
# APPENDED GENRE
# 206
# https://api.spotify.com/v1/search?q=weird+inside&type=artist
# 200
# APPENDED GENRE
# 207
# https://api.spotify.com/v1/search?q=Flamingosis&type=artist
# 200
# APPENDED GENRE
# 208
# https://api.spotify.com/v1/search?q=B0nds&type=artist
# 200
# APPENDED GENRE
# 209
# https://api.spotify.com/v1/search?q=mt.+fujitive&type=artist
# 200
# APPENDED GENRE
# 210
# https://api.spotify.com/v1/search?q=Pete+Rock&type=artist
# 200
# APPENDED GENRE
# 211
# https://api.spotify.com/v1/search?q=Mujo&type=artist
# 200
# APPENDED GENRE
# 212
# https://api.spotify.com/v1/search?q=Brenky&type=artist
# 200
# APPENDED GENRE
# 213
# https://api.spotify.com/v1/search?q=Wun+Two&type=artist
# 200
# APPENDED GENRE
# 214
# https://api.spotify.com/v1/search?q=Ikane+C.&type=artist
# 200
# APPENDED GENRE
# 215
# https://api.spotify.com/v1/search?q=Manny&type=artist
# 200
# APPENDED GENRE
# 216
# https://api.spotify.com/v1/search?q=SwuM&type=artist
# 200
# APPENDED GENRE
# 217
# https://api.spotify.com/v1/search?q=Arbour&type=artist
# 200
# APPENDED GENRE
# 218
# https://api.spotify.com/v1/search?q=Sugar+Cane+Davis&type=artist
# 200
# APPENDED GENRE
# 219
# https://api.spotify.com/v1/search?q=Monma&type=artist
# 200
# APPENDED GENRE
# 220
# https://api.spotify.com/v1/search?q=o+k+h+o&type=artist
# 200
# APPENDED GENRE
# 221
# https://api.spotify.com/v1/search?q=Jinsang&type=artist
# 200
# APPENDED GENRE
# 222
# https://api.spotify.com/v1/search?q=halberd&type=artist
# 200
# APPENDED GENRE
# 223
# https://api.spotify.com/v1/search?q=Toonorth&type=artist
# 200
# APPENDED GENRE
# 224
# https://api.spotify.com/v1/search?q=fantompower&type=artist
# 200
# APPENDED GENRE
# 225
# https://api.spotify.com/v1/search?q=Maple+Syrup&type=artist
# 200
# APPENDED GENRE
# 226
# https://api.spotify.com/v1/search?q=Flughand&type=artist
# 200
# APPENDED GENRE
# 227
# https://api.spotify.com/v1/search?q=Sky.High&type=artist
# 200
# APPENDED GENRE
# 228
# https://api.spotify.com/v1/search?q=Made+in+M&type=artist
# 200
# APPENDED GENRE
# 229
# https://api.spotify.com/v1/search?q=H+E+R+B&type=artist
# 200
# APPENDED GENRE
# 230
# https://api.spotify.com/v1/search?q=Sweeps&type=artist
# 200
# APPENDED GENRE
# 231
# https://api.spotify.com/v1/search?q=santpoort&type=artist
# 200
# APPENDED GENRE
# 232
# https://api.spotify.com/v1/search?q=Two+Sleepy&type=artist
# 200
# APPENDED GENRE
# 233
# https://api.spotify.com/v1/search?q=Joe+Corfield&type=artist
# 200
# APPENDED GENRE
# 234
# https://api.spotify.com/v1/search?q=C+Y+G+N&type=artist
# 200
# APPENDED GENRE
# 235
# https://api.spotify.com/v1/search?q=Dil+Withers&type=artist
# 200
# APPENDED GENRE
# 236
# https://api.spotify.com/v1/search?q=Kassandra&type=artist
# 200
# APPENDED GENRE
# 237
# https://api.spotify.com/v1/search?q=Flovry&type=artist
# 200
# APPENDED GENRE
# 238
# https://api.spotify.com/v1/search?q=Bassti&type=artist
# 200
# APPENDED GENRE
# 239
# https://api.spotify.com/v1/search?q=Tesk&type=artist
# 200
# APPENDED GENRE
# 240
# https://api.spotify.com/v1/search?q=Saiko&type=artist
# 200
# APPENDED GENRE
# 241
# https://api.spotify.com/v1/search?q=Phoniks&type=artist
# 200
# APPENDED GENRE
# 242
# https://api.spotify.com/v1/search?q=GlobulDub&type=artist
# 200
# APPENDED GENRE
# 243
# https://api.spotify.com/v1/search?q=Ajmw&type=artist
# 200
# APPENDED GENRE
# 244
# https://api.spotify.com/v1/search?q=eli+filosov+%5B+p+h+i+l+o+%5D&type=artist
# 200
# APPENDED GENRE
# 245
# https://api.spotify.com/v1/search?q=Kendall+Miles&type=artist
# 200
# APPENDED GENRE
# 246
# https://api.spotify.com/v1/search?q=Vhsceral&type=artist
# 200
# APPENDED GENRE
# 247
# https://api.spotify.com/v1/search?q=WISDOM&type=artist
# 200
# APPENDED GENRE
# 248
# https://api.spotify.com/v1/search?q=invention_&type=artist
# 200
# APPENDED GENRE
# 249
# https://api.spotify.com/v1/search?q=Roberto+Echo&type=artist
# 200
# APPENDED GENRE
# 250
# https://api.spotify.com/v1/search?q=Misc.Inc&type=artist
# 200
# APPENDED GENRE
# 251
# https://api.spotify.com/v1/search?q=Sleepdealer&type=artist
# 200
# APPENDED GENRE
# 252
# https://api.spotify.com/v1/search?q=Ruel&type=artist
# 200
# APPENDED GENRE
# 253
# https://api.spotify.com/v1/search?q=The+Prince+Karma&type=artist
# 200
# APPENDED GENRE
# 254
# https://api.spotify.com/v1/search?q=Benny+Benassi&type=artist
# 200
# APPENDED GENRE
# 255
# https://api.spotify.com/v1/search?q=Janet+Jackson&type=artist
# 200
# APPENDED GENRE
# 256
# https://api.spotify.com/v1/search?q=Chief+Keef&type=artist
# 200
# APPENDED GENRE
# 257
# https://api.spotify.com/v1/search?q=Yung+Lean&type=artist
# 200
# APPENDED GENRE
# 258
# https://api.spotify.com/v1/search?q=Evil+Needle&type=artist
# 200
# APPENDED GENRE
# 259
# https://api.spotify.com/v1/search?q=chief.&type=artist
# 200
# APPENDED GENRE
# 260
# https://api.spotify.com/v1/search?q=Bertholet&type=artist
# 200
# APPENDED GENRE
# 261
# https://api.spotify.com/v1/search?q=Philanthrope&type=artist
# 200
# APPENDED GENRE
# 262
# https://api.spotify.com/v1/search?q=Raging+Moses&type=artist
# 200
# APPENDED GENRE
# 263
# https://api.spotify.com/v1/search?q=Leavv&type=artist
# 200
# APPENDED GENRE
# 264
# https://api.spotify.com/v1/search?q=BLVTH&type=artist
# 200
# APPENDED GENRE
# 265
# https://api.spotify.com/v1/search?q=Erick+the+Architect&type=artist
# 200
# APPENDED GENRE
# 266
# https://api.spotify.com/v1/search?q=Knxwledge&type=artist
# 200
# APPENDED GENRE
# 267
# https://api.spotify.com/v1/search?q=McCoy+Tyner&type=artist
# 200
# APPENDED GENRE
# 268
# https://api.spotify.com/v1/search?q=Rook1e&type=artist
# 200
# APPENDED GENRE
# 269
# https://api.spotify.com/v1/search?q=Slim.&type=artist
# 200
# APPENDED GENRE
# 270
# https://api.spotify.com/v1/search?q=Ozoyo&type=artist
# 200
# APPENDED GENRE
# 271
# https://api.spotify.com/v1/search?q=Walterwarm&type=artist
# 200
# APPENDED GENRE
# 272
# https://api.spotify.com/v1/search?q=Moo+Latte&type=artist
# 200
# APPENDED GENRE
# 273
# https://api.spotify.com/v1/search?q=Epifania&type=artist
# 200
# APPENDED GENRE
# 274
# https://api.spotify.com/v1/search?q=Minthaze&type=artist
# 200
# APPENDED GENRE
# 275
# https://api.spotify.com/v1/search?q=Burbank&type=artist
# 200
# APPENDED GENRE
# 276
# https://api.spotify.com/v1/search?q=jhfly&type=artist
# 200
# APPENDED GENRE
# 277
# https://api.spotify.com/v1/search?q=Mndsgn&type=artist
# 200
# APPENDED GENRE
# 278
# https://api.spotify.com/v1/search?q=Lester+Nowhere&type=artist
# 200
# APPENDED GENRE
# 279
# https://api.spotify.com/v1/search?q=Lungfulls&type=artist
# 200
# APPENDED GENRE
# 280
# https://api.spotify.com/v1/search?q=TreeHouse+707&type=artist
# 200
# APPENDED GENRE
# 281
# https://api.spotify.com/v1/search?q=Nymano&type=artist
# 200
# APPENDED GENRE
# 282
# https://api.spotify.com/v1/search?q=Brock+Berrigan&type=artist
# 200
# APPENDED GENRE
# 283
# https://api.spotify.com/v1/search?q=Flying+Lotus&type=artist
# 200
# APPENDED GENRE
# 284
# https://api.spotify.com/v1/search?q=Killer+Bee&type=artist
# 200
# APPENDED GENRE
# 285
# https://api.spotify.com/v1/search?q=aimless&type=artist
# 200
# APPENDED GENRE
# 286
# https://api.spotify.com/v1/search?q=Hydrogenii&type=artist
# 200
# APPENDED GENRE
# 287
# https://api.spotify.com/v1/search?q=GwaiLow&type=artist
# 200
# APPENDED GENRE
# 288
# https://api.spotify.com/v1/search?q=twuan&type=artist
# 200
# APPENDED GENRE
# 289
# https://api.spotify.com/v1/search?q=omniboi&type=artist
# 200
# APPENDED GENRE
# 290
# https://api.spotify.com/v1/search?q=Saib&type=artist
# 200
# APPENDED GENRE
# 291
# https://api.spotify.com/v1/search?q=VIK&type=artist
# 200
# APPENDED GENRE
# 292
# https://api.spotify.com/v1/search?q=Comodo&type=artist
# 200
# APPENDED GENRE
# 293
# https://api.spotify.com/v1/search?q=Dream+Koala&type=artist
# 200
# APPENDED GENRE
# 294
# https://api.spotify.com/v1/search?q=Smika&type=artist
# 200
# APPENDED GENRE
# 295
# https://api.spotify.com/v1/search?q=Smuv&type=artist
# 200
# APPENDED GENRE
# 296
# https://api.spotify.com/v1/search?q=ProducerTrentTaylor&type=artist
# 200
# APPENDED GENRE
# 297
# https://api.spotify.com/v1/search?q=quickly%2C+quickly&type=artist
# 200
# APPENDED GENRE
# 298
# https://api.spotify.com/v1/search?q=Bluedoom&type=artist
# 200
# APPENDED GENRE
# 299
# https://api.spotify.com/v1/search?q=HM+Surf&type=artist
# 200
# APPENDED GENRE
# 300
# https://api.spotify.com/v1/search?q=Chris+Anderson&type=artist
# 200
# APPENDED GENRE
# 301
# https://api.spotify.com/v1/search?q=Chris+Mazuera&type=artist
# 200
# APPENDED GENRE
# 302
# https://api.spotify.com/v1/search?q=Bodikhuu&type=artist
# 200
# APPENDED GENRE
# 303
# https://api.spotify.com/v1/search?q=Seneca+B&type=artist
# 200
# APPENDED GENRE
# 304
# https://api.spotify.com/v1/search?q=mommy&type=artist
# 200
# APPENDED GENRE
# 305
# https://api.spotify.com/v1/search?q=Mono%3AMassive&type=artist
# 200
# APPENDED GENRE
# 306
# https://api.spotify.com/v1/search?q=Jazzinuf&type=artist
# 200
# APPENDED GENRE
# 307
# https://api.spotify.com/v1/search?q=Cloudchord&type=artist
# 200
# APPENDED GENRE
# 308
# https://api.spotify.com/v1/search?q=Slumberville&type=artist
# 200
# APPENDED GENRE
# 309
# https://api.spotify.com/v1/search?q=Allmos&type=artist
# 200
# APPENDED GENRE
# 310
# https://api.spotify.com/v1/search?q=leaf+beach&type=artist
# 200
# APPENDED GENRE
# 311
# https://api.spotify.com/v1/search?q=Ian+Ewing&type=artist
# 200
# APPENDED GENRE
# 312
# https://api.spotify.com/v1/search?q=Dweeb&type=artist
# 200
# APPENDED GENRE
# 313
# https://api.spotify.com/v1/search?q=Dirty+Art+Club&type=artist
# 200
# APPENDED GENRE
# 314
# https://api.spotify.com/v1/search?q=Twit+One&type=artist
# 200
# APPENDED GENRE
# 315
# https://api.spotify.com/v1/search?q=luvwn&type=artist
# 200
# APPENDED GENRE
# 316
# https://api.spotify.com/v1/search?q=Smeyeul.&type=artist
# 200
# APPENDED GENRE
# 317
# https://api.spotify.com/v1/search?q=Rae+Sremmurd&type=artist
# 200
# APPENDED GENRE
# 318
# https://api.spotify.com/v1/search?q=Migos&type=artist
# 200
# APPENDED GENRE
# 319
# https://api.spotify.com/v1/search?q=Yung+Bans&type=artist
# 200
# APPENDED GENRE
# 320
# https://api.spotify.com/v1/search?q=Playboi+Carti&type=artist
# 200
# APPENDED GENRE
# 321
# https://api.spotify.com/v1/search?q=YBN+Nahmir&type=artist
# 200
# APPENDED GENRE
# 322
# https://api.spotify.com/v1/search?q=Kap+G&type=artist
# 200
# APPENDED GENRE
# 323
# https://api.spotify.com/v1/search?q=Nebu+Kiniza&type=artist
# 200
# APPENDED GENRE
# 324
# https://api.spotify.com/v1/search?q=YBN+Almighty+Jay&type=artist
# 200
# APPENDED GENRE
# 325
# https://api.spotify.com/v1/search?q=Valee&type=artist
# 200
# APPENDED GENRE
# 326
# https://api.spotify.com/v1/search?q=Sticky+Fingers&type=artist
# 200
# APPENDED GENRE
# 327
# https://api.spotify.com/v1/search?q=Bryson+Tiller&type=artist
# 200
# APPENDED GENRE
# 328
# https://api.spotify.com/v1/search?q=Jazmine+Sullivan&type=artist
# 200
# APPENDED GENRE
# 329
# https://api.spotify.com/v1/search?q=Kygo&type=artist
# 200
# APPENDED GENRE
# 330
# https://api.spotify.com/v1/search?q=half%C3%A2%E2%82%AC%C2%A2alive&type=artist
# 200
# APPENDED GENRE
# 331
# https://api.spotify.com/v1/search?q=The+Script&type=artist
# 200
# APPENDED GENRE
# 332
# https://api.spotify.com/v1/search?q=Bastille&type=artist
# 200
# APPENDED GENRE
# 333
# https://api.spotify.com/v1/search?q=Kodaline&type=artist
# 200
# APPENDED GENRE
# 334
# https://api.spotify.com/v1/search?q=COIN&type=artist
# 200
# APPENDED GENRE
# 335
# https://api.spotify.com/v1/search?q=The+Fray&type=artist
# 200
# APPENDED GENRE
# 336
# https://api.spotify.com/v1/search?q=Ricky+Montgomery&type=artist
# 200
# APPENDED GENRE
# 337
# https://api.spotify.com/v1/search?q=X+Ambassadors&type=artist
# 200
# APPENDED GENRE
# 338
# https://api.spotify.com/v1/search?q=Wild+Party&type=artist
# 200
# APPENDED GENRE
# 339
# https://api.spotify.com/v1/search?q=Sloppy+Toaster&type=artist
# 200
# APPENDED GENRE
# 340
# https://api.spotify.com/v1/search?q=Ceramic+Animal&type=artist
# 200
# APPENDED GENRE
# 341
# https://api.spotify.com/v1/search?q=The+Grinns&type=artist
# 200
# APPENDED GENRE
# 342
# https://api.spotify.com/v1/search?q=Zedd&type=artist
# 200
# APPENDED GENRE
# 343
# https://api.spotify.com/v1/search?q=Whethan&type=artist
# 200
# APPENDED GENRE
# 344
# https://api.spotify.com/v1/search?q=Lauv&type=artist
# 200
# APPENDED GENRE
# 345
# https://api.spotify.com/v1/search?q=Madison+Beer&type=artist
# 200
# APPENDED GENRE
# 346
# https://api.spotify.com/v1/search?q=Action+Bronson&type=artist
# 200
# APPENDED GENRE
# 347
# https://api.spotify.com/v1/search?q=Rejjie+Snow&type=artist
# 200
# APPENDED GENRE
# 348
# https://api.spotify.com/v1/search?q=Cheat+Codes&type=artist
# 200
# APPENDED GENRE
# 349
# https://api.spotify.com/v1/search?q=Fetty+Wap&type=artist
# 200
# APPENDED GENRE
# 350
# https://api.spotify.com/v1/search?q=A%24AP+Rocky&type=artist
# 200
# APPENDED GENRE
# 351
# https://api.spotify.com/v1/search?q=J.+Cole&type=artist
# 200
# APPENDED GENRE
# 352
# https://api.spotify.com/v1/search?q=Tyga&type=artist
# 200
# APPENDED GENRE
# 353
# https://api.spotify.com/v1/search?q=Rob+Cantor&type=artist
# 200
# APPENDED GENRE
# 354
# https://api.spotify.com/v1/search?q=Juan+Rios&type=artist
# 200
# APPENDED GENRE
# 355
# https://api.spotify.com/v1/search?q=Ameba&type=artist
# 200
# APPENDED GENRE
# 356
# https://api.spotify.com/v1/search?q=David+Chief&type=artist
# 200
# APPENDED GENRE
# 357
# https://api.spotify.com/v1/search?q=Thelonious+Martin&type=artist
# 200
# APPENDED GENRE
# 358
# https://api.spotify.com/v1/search?q=Ckwnce&type=artist
# 200
# APPENDED GENRE
# 359
# https://api.spotify.com/v1/search?q=Ricky+Marano&type=artist
# 200
# APPENDED GENRE
# 360
# https://api.spotify.com/v1/search?q=Harris+Cole&type=artist
# 200
# APPENDED GENRE
# 361
# https://api.spotify.com/v1/search?q=Kuranes&type=artist
# 200
# APPENDED GENRE
# 362
# https://api.spotify.com/v1/search?q=TiMT&type=artist
# 200
# APPENDED GENRE
# 363
# https://api.spotify.com/v1/search?q=w%C3%83%C2%BCsh&type=artist
# 200
# APPENDED GENRE
# 364
# https://api.spotify.com/v1/search?q=Oddfish&type=artist
# 200
# APPENDED GENRE
# 365
# https://api.spotify.com/v1/search?q=Sofasound&type=artist
# 200
# APPENDED GENRE
# 366
# https://api.spotify.com/v1/search?q=Kazam&type=artist
# 200
# APPENDED GENRE
# 367
# https://api.spotify.com/v1/search?q=Keem+the+Cipher&type=artist
# 200
# APPENDED GENRE
# 368
# https://api.spotify.com/v1/search?q=Estugarda&type=artist
# 200
# APPENDED GENRE
# 369
# https://api.spotify.com/v1/search?q=RudeManners&type=artist
# 200
# APPENDED GENRE
# 370
# https://api.spotify.com/v1/search?q=oxela&type=artist
# 200
# APPENDED GENRE
# 371
# https://api.spotify.com/v1/search?q=Cr%C3%83%C2%A1neo&type=artist
# 200
# APPENDED GENRE
# 372
# https://api.spotify.com/v1/search?q=Samwise&type=artist
# 200
# APPENDED GENRE
# 373
# https://api.spotify.com/v1/search?q=Lo%27fi+Boy&type=artist
# 200
# APPENDED GENRE
# 374
# https://api.spotify.com/v1/search?q=Pandrezz&type=artist
# 200
# APPENDED GENRE
# 375
# https://api.spotify.com/v1/search?q=In+Love+With+a+Ghost&type=artist
# 200

# %%
genreKey = dict(zip(artists, genreList))

# %%
genreKey['Zedd']

# %%
dfGenres = pd.DataFrame({'artistName':artists, 'genres':genreList})

# %%
rawHist
# Out:
#                 endTime           artistName                    trackName  \
# 0      2018-11-14 00:01      Imagine Dragons                        Stuck
# 1      2018-11-14 00:04      Imagine Dragons                         Love
# 2      2018-11-14 00:08      Imagine Dragons                        Birds
# 3      2018-11-14 00:12      Imagine Dragons                     Burn Out
# 4      2018-11-14 00:16      Imagine Dragons                    Real Life
# ...                 ...                  ...                          ...
# 30822  2019-11-14 23:32  My Chemical Romance  Welcome to the Black Parade
# 30823  2019-11-14 23:34          Tony Molina               Jasper's Theme
# 30824  2019-11-14 23:38      Imagine Dragons                     Cool Out
# 30825  2019-11-14 23:41  5 Seconds of Summer          If Walls Could Talk
# 30826  2019-11-14 23:44      Imagine Dragons                    Boomerang
#
#        msPlayed
# 0        190853
# 1        166360
# 2        219440
# 3        273880
# 4        247546
# ...         ...
# 30822    311106
# 30823    121509
# 30824    217866
# 30825    182292
# 30826    187800
#
# [30827 rows x 4 columns]

# %%
def appendGenres(row):
    artist = row['artistName']
    return genreKey[artist]

# %%
genreCol = rawHist.apply(appendGenres, axis=1)
hist = rawHist.assign(genre = genreCol)

# %%
hist
# Out:
#                 endTime           artistName                    trackName  \
# 0      2018-11-14 00:01      Imagine Dragons                        Stuck
# 1      2018-11-14 00:04      Imagine Dragons                         Love
# 2      2018-11-14 00:08      Imagine Dragons                        Birds
# 3      2018-11-14 00:12      Imagine Dragons                     Burn Out
# 4      2018-11-14 00:16      Imagine Dragons                    Real Life
# ...                 ...                  ...                          ...
# 30822  2019-11-14 23:32  My Chemical Romance  Welcome to the Black Parade
# 30823  2019-11-14 23:34          Tony Molina               Jasper's Theme
# 30824  2019-11-14 23:38      Imagine Dragons                     Cool Out
# 30825  2019-11-14 23:41  5 Seconds of Summer          If Walls Could Talk
# 30826  2019-11-14 23:44      Imagine Dragons                    Boomerang
#
#        msPlayed                                             genre
# 0        190853                               [modern rock, rock]
# 1        166360                               [modern rock, rock]
# 2        219440                               [modern rock, rock]
# 3        273880                               [modern rock, rock]
# 4        247546                               [modern rock, rock]
# ...         ...                                               ...
# 30822    311106                      [emo, modern rock, pop punk]
# 30823    121509  [indie punk, modern folk rock, modern power pop]
# 30824    217866                               [modern rock, rock]
# 30825    182292         [boy band, dance pop, pop, post-teen pop]
# 30826    187800                               [modern rock, rock]
#
# [30827 rows x 5 columns]

# %%
enc = OneHotEncoder()

# %%
hist = hist.dropna()
hist.isna().mean()
# Out:
# endTime       0.0
# artistName    0.0
# trackName     0.0
# msPlayed      0.0
# genre         0.0
# dtype: float64

# %%
temp = []
for i in genreKey.values():
    if type(i) == list:
        for j in i:
            temp.append(j)

# %%
genres = pd.Series(temp).unique()
